# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import requests
import pandas as pd

# %%
url='https://www.nike.com/il/w/womens-sale-tops-t-shirts-3yaepz5e1x6z9om13'
browser=webdriver.Chrome()
browser.get(url)
print(browser.title)
browser.find_element(By.XPATH,'/html/body/div[3]/div/div[1]/div/div[2]/div/div[2]/div[2]/button').click()

body_elem=browser.find_element(By.TAG_NAME,'body')
scrool=100
while scrool:
    body_elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    scrool-=1


products=browser.find_elements(By.CLASS_NAME,'product-card__title')
atags=browser.find_elements(By.CLASS_NAME,'product-card__link-overlay')


#________________
products_name=[product.text for product in products]
links=[link.get_attribute('href') for link in atags]

time.sleep(3)
browser.close()
# Out:
# Women's Sale Tops & T-Shirts. Nike IL

# %%
pd.DataFrame({'Product':products_name,'Links':links})
# Out:
#                                 Product  \
# 0               Nike Dri-FIT Swoosh Run
# 1                    Nike Dri-FIT Pacer
# 2                                  Nike
# 3                   Nike Dri-FIT Swoosh
# 4                      Nike Dri-FIT One
# ..                                  ...
# 205                              Jordan
# 206                   Jordan (Her)itage
# 207  Chelsea F.C. 2022/23 Stadium Third
# 208       Netherlands 2022 Stadium Home
# 209           Nike Sportswear Tech Pack
#
#                                                  Links
# 0    https://www.nike.com/il/t/dri-fit-swoosh-run-s...
# 1    https://www.nike.com/il/t/dri-fit-pacer-1-4-zi...
# 2    https://www.nike.com/il/t/element-1-2-zip-runn...
# 3    https://www.nike.com/il/t/dri-fit-swoosh-1-4-z...
# 4    https://www.nike.com/il/t/dri-fit-one-graphic-...
# ..                                                 ...
# 205  https://www.nike.com/il/t/jordan-long-sleeve-v...
# ...
